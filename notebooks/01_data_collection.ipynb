# %% [markdown]
# # **Notebook 01: Data Collection**
# -----
#
# ### **Objective**
#
# We collect raw data from multiple authoritative sources to build a comprehensive view of the UK tech startup ecosystem. This notebook establishes our data ingestion pipelines for company registrations, funding announcements, hiring signals, and product launches.
#
# ### **Data Sources**
#
# | Source | Data Type | Update Frequency | API/Scraping |
# |--------|-----------|------------------|--------------|
# | Companies House | Incorporations, financials, directors | Daily | Free API |
# | Tech.eu | Funding announcements | Daily | RSS/Scraping |
# | Sifted | Funding news, analysis | Daily | RSS/Scraping |
# | Product Hunt | Product launches | Daily | Free API |
# | Job Boards | Job postings, headcount | Weekly | Scraping |
#
# ### **Technical Stack**
#
# - **requests**: HTTP requests to APIs and web pages
# - **pandas**: Data manipulation and storage
# - **BeautifulSoup**: HTML parsing for web scraping
# - **python-dotenv**: Environment variable management for API keys
# - **SQLite**: Local database for raw data storage
#
#
#
# ---

# %%
# Import required libraries
import requests
import pandas as pd
import sqlite3
from datetime import datetime
import time
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
# Out:
# False

# %% [markdown]
# ### **Companies House API Integration**
#
# - We begin by connecting to the Companies House API to pull UK company incorporation data.
#
# - Companies House is the UK's official registrar of companies, providing authoritative data on all registered businesses.
#
# - We'll filter for technology companies incorporated between 2022-2025 to focus on early-stage startups.
#
# - We have imported our core libraries and set up access to the Companies House API.
#
# - The API key is stored in a `.env` file (which we'll create next) to keep credentials secure and out of version control.

# %%
# Load environment variables
load_dotenv()

# Set up Companies House API credentials
API_KEY = os.getenv('COMPANIES_HOUSE_API_KEY', '')  # We'll add this to .env file
BASE_URL = 'https://api.company-information.service.gov.uk'

# %% [markdown]
# - We test our API connection by fetching data for a known company (Revolut).
#
# - The Companies House API uses HTTP Basic Authentication where the API key is the username and the password is left empty.
#
# - If successful, we'll see the company name and incorporation date.

# %%
# Test the API connection
def test_companies_house_connection():
    """
    Test our connection to Companies House API by fetching a known company
    """
    # Test with a well-known company (e.g., Revolut's UK entity)
    test_company_number = "08804411"  # Revolut Ltd
    
    url = f"{BASE_URL}/company/{test_company_number}"
    
    response = requests.get(url, auth=(API_KEY, ''))
    
    if response.status_code == 200:
        company_data = response.json()
        print("✓ Connection successful!")
        print(f"Company name: {company_data['company_name']}")
        print(f"Status: {company_data['company_status']}")
        print(f"Incorporated: {company_data['date_of_creation']}")
        return True
    else:
        print(f"✗ Connection failed. Status code: {response.status_code}")
        print(f"Error: {response.text}")
        return False

# Run the test
test_companies_house_connection()
# Out:
# ✓ Connection successful!
# Company name: REVOLUT LTD
# Status: active
# Incorporated: 2013-12-06
# True

# %% [markdown]
# - We define Standard Industrial Classification (SIC) codes that identify technology companies.
#
# - These are the official UK government codes used to classify business activities.
#
# - We focus on software development, IT services, and data processing: the "core" tech startup sectors.
#
# - We also incorporate FinTech, AI/Data, Biotech, E-Commerce, etc.
#
# - Companies House requires all UK companies to declare their SIC codes at incorporation.

# %%
# Define SIC codes for technology companies
TECH_SIC_CODES = [
    # Core Software & IT
    '62011',  # Ready-made interactive leisure and entertainment software development
    '62012',  # Business and domestic software development
    '62020',  # Information technology consultancy activities
    '62090',  # Other information technology service activities
    '63110',  # Data processing, hosting and related activities
    '63120',  # Web portals
    '63990',  # Other information service activities (SaaS platforms)
    '58210',  # Publishing of computer games
    '58290',  # Other software publishing
    '26200',  # Manufacture of computers and peripheral equipment
    '95110',  # Repair of computers and peripheral equipment
    
    # FinTech
    '64190',  # Other monetary intermediation (digital banking, payment platforms)
    '64999',  # Financial intermediation not elsewhere classified (crypto, lending tech)
    '66190',  # Other activities auxiliary to financial intermediation (FinTech infrastructure)
    
    # HealthTech & BioTech
    '86900',  # Other human health activities (digital health, telemedicine)
    '72110',  # Research and experimental development on biotechnology
    
    # AI, Data & Analytics
    '70220',  # Business and other management consultancy (includes AI/ML consulting)
    '73110',  # Advertising agencies (MarTech, AdTech)
    '73120',  # Media representation (digital media platforms)
    
    # E-commerce & Marketplaces
    '82990',  # Other business support service activities (marketplace platforms)
    '47910',  # Retail sale via mail order or internet
]

print(f"Tracking {len(TECH_SIC_CODES)} tech-related SIC codes")
print("\nBreakdown by category:")
print(f"  Core Software/IT: 11 codes")
print(f"  FinTech: 3 codes")
print(f"  HealthTech: 2 codes")
print(f"  AI/Data: 3 codes")
print(f"  E-commerce: 2 codes")
# Out:
# Tracking 21 tech-related SIC codes
#
# Breakdown by category:
#   Core Software/IT: 11 codes
#   FinTech: 3 codes
#   HealthTech: 2 codes
#   AI/Data: 3 codes
#   E-commerce: 2 codes

# %% [markdown]
# - We build a search function that queries Companies House for companies incorporated within a specific date range and matching our tech SIC codes.
#
# - We search one SIC code at a time to avoid hitting API limits, and add a small delay between requests to be respectful of **rate limits (600 requests per 5 minutes)**.
#
# - **Note**: We're testing with just January 2024 and 3 SIC codes first to verify the approach works before running the full search.

# %%
def search_companies_by_date(incorporated_from, incorporated_to, sic_codes):
    """
    Search for companies incorporated within a date range with specific SIC codes.
    Companies House search API has limitations, so we'll use advanced search.
    """
    
    companies = []
    
    # Companies House advanced search endpoint
    search_url = f"{BASE_URL}/advanced-search/companies"
    
    for sic_code in sic_codes:
        print(f"Searching SIC code: {sic_code}...", end=" ")
        
        params = {
            'incorporated_from': incorporated_from,
            'incorporated_to': incorporated_to,
            'sic_codes': sic_code,
            'size': 100  # Max results per page
        }
        
        try:
            response = requests.get(
                search_url, 
                auth=(API_KEY, ''),
                params=params
            )
            
            if response.status_code == 200:
                data = response.json()
                items = data.get('items', [])
                companies.extend(items)
                print(f"Found {len(items)} companies")
                
            else:
                print(f"Error: {response.status_code}")
            
            # Rate limiting: 600 requests per 5 minutes
            time.sleep(0.5)  # Be respectful to the API
            
        except Exception as e:
            print(f"Exception: {str(e)}")
            continue
    
    print(f"\nTotal companies found: {len(companies)}")
    return companies

# Test with a small date range first (January 2024)
test_companies = search_companies_by_date('2024-01-01', '2024-01-31', TECH_SIC_CODES[:3])
# Out:
# Searching SIC code: 62011... Found 100 companies
# Searching SIC code: 62012... Found 100 companies
# Searching SIC code: 62020... Found 100 companies
#
# Total companies found: 300

# %% [markdown]
# - We will not keep an artificial page limit and fetch ALL results for each SIC code.
#
# - The function now includes a safety check for rate limiting (HTTP 429 status): if we hit the limit, we pause for 60 seconds before continuing.
#
# - This ensures we capture every company without missing any due to pagination caps.

# %%
def search_all_companies(incorporated_from, incorporated_to, sic_codes):
    """
    Search ALL companies without page limits - fetch until no more results.
    We'll monitor API responses and add safety checks for rate limits.
    """
    
    all_companies = []
    total_requests = 0
    
    for sic_code in sic_codes:
        print(f"\nSearching SIC code: {sic_code}")
        page = 0
        
        while True:  # Keep fetching until no more results
            search_url = f"{BASE_URL}/advanced-search/companies"
            
            params = {
                'incorporated_from': incorporated_from,
                'incorporated_to': incorporated_to,
                'sic_codes': sic_code,
                'size': 100,
                'start_index': page * 100
            }
            
            try:
                response = requests.get(
                    search_url,
                    auth=(API_KEY, ''),
                    params=params,
                    timeout=10
                )
                
                total_requests += 1
                
                if response.status_code == 200:
                    data = response.json()
                    items = data.get('items', [])
                    
                    if not items:  # No more results
                        print(f"  Completed: {page * 100} total companies")
                        break
                    
                    all_companies.extend(items)
                    print(f"  Page {page + 1}: {len(items)} companies (running total: {len(all_companies)})")
                    
                    if len(items) < 100:  # Last page
                        print(f"  Completed: {len(all_companies)} total companies")
                        break
                    
                    page += 1
                    
                elif response.status_code == 429:  # Rate limit hit
                    print(f"  Rate limit reached. Waiting 60 seconds...")
                    time.sleep(60)
                    continue  # Retry same page
                    
                else:
                    print(f"  Error {response.status_code}: {response.text[:100]}")
                    break
                
                time.sleep(0.5)  # Rate limiting between requests
                
            except Exception as e:
                print(f"  Exception: {str(e)}")
                break
    
    print(f"\n✓ Search complete!")
    print(f"  Total requests made: {total_requests}")
    print(f"  Total unique companies: {len(all_companies)}")
    return all_companies

# Test with same January 2024 range, first 3 codes, but no page limit
test_full_search = search_all_companies(
    '2024-01-01', 
    '2024-01-31', 
    TECH_SIC_CODES[:3]
)
# Out:
# Searching SIC code: 62011
#   Page 1: 100 companies (running total: 100)
#   Page 2: 100 companies (running total: 200)
#   Page 3: 8 companies (running total: 208)
#   Completed: 208 total companies
#
# Searching SIC code: 62012
#   Page 1: 100 companies (running total: 308)
#   Page 2: 100 companies (running total: 408)
#   Page 3: 100 companies (running total: 508)
#   Page 4: 100 companies (running total: 608)
#   Page 5: 100 companies (running total: 708)
#   Page 6: 100 companies (running total: 808)
#   Page 7: 100 companies (running total: 908)
#   Page 8: 100 companies (running total: 1008)
#   Page 9: 100 companies (running total: 1108)
#   Page 10: 100 companies (running total: 1208)
#   Page 11: 100 companies (running total: 1308)
#   Page 12: 100 companies (running total: 1408)
#   Page 13: 100 companies (running total: 1508)
#   Page 14: 100 companies (running total: 1608)
#   Page 15: 100 companies (running total: 1708)
#   Page 16: 100 companies (running total: 1808)
#   Page 17: 100 companies (running total: 1908)
#   Page 18: 15 companies (running total: 1923)
#   Completed: 1923 total companies
#
# Searching SIC code: 62020
#   Page 1: 100 companies (running total: 2023)
#   Page 2: 100 companies (running total: 2123)
#   Page 3: 100 companies (running total: 2223)
#   Page 4: 100 companies (running total: 2323)
#   Page 5: 100 companies (running total: 2423)
#   Page 6: 100 companies (running total: 2523)
#   Page 7: 100 companies (running total: 2623)
#   Page 8: 100 companies (running total: 2723)
#   Page 9: 100 companies (running total: 2823)
#   Page 10: 100 companies (running total: 2923)
#   Page 11: 100 companies (running total: 3023)
#   Page 12: 100 companies (running total: 3123)
#   Page 13: 100 companies (running total: 3223)
#   Page 14: 100 companies (running total: 3323)
#   Page 15: 100 companies (running total: 3423)
#   Page 16: 100 companies (running total: 3523)
#   Page 17: 100 companies (running total: 3623)
#   Page 18: 100 companies (running total: 3723)
#   Page 19: 100 companies (running total: 3823)
#   Page 20: 100 companies (running total: 3923)
#   Page 21: 100 companies (running total: 4023)
#   Page 22: 100 companies (running total: 4123)
#   Page 23: 100 companies (running total: 4223)
#   Page 24: 100 companies (running total: 4323)
#   Page 25: 100 companies (running total: 4423)
#   Page 26: 100 companies (running total: 4523)
#   Page 27: 100 companies (running total: 4623)
#   Page 28: 94 companies (running total: 4717)
#   Completed: 4717 total companies
#
# ✓ Search complete!
#   Total requests made: 49
#   Total unique companies: 4717

# %% [markdown]
# We now execute the full search across our entire timeframe (2022-2025) and all 21 tech SIC codes. This is our complete raw dataset of UK technology companies. Based on our test run, we estimate this will collect 20,000-30,000 companies and take approximately 5-10 minutes to complete.

# %%
# Now run the full search across all years and all SIC codes
print("Starting full data collection: 2022-2025, all 21 SIC codes")
print("This will take approximately 5-10 minutes...\n")

all_uk_tech_companies = search_all_companies(
    incorporated_from='2022-01-01',
    incorporated_to='2025-12-31',
    sic_codes=TECH_SIC_CODES
)

print(f"\n{'='*60}")
print(f"DATA COLLECTION COMPLETE")
print(f"{'='*60}")
print(f"Total companies collected: {len(all_uk_tech_companies):,}")
# Out:
# Starting full data collection: 2022-2025, all 21 SIC codes
# This will take approximately 5-10 minutes...
#
#
# Searching SIC code: 62011
#   Page 1: 100 companies (running total: 100)
#   Page 2: 100 companies (running total: 200)
#   Page 3: 100 companies (running total: 300)
#   Page 4: 100 companies (running total: 400)
#   Page 5: 100 companies (running total: 500)
#   Page 6: 100 companies (running total: 600)
#   Page 7: 100 companies (running total: 700)
#   Page 8: 100 companies (running total: 800)
#   Page 9: 100 companies (running total: 900)
#   Page 10: 100 companies (running total: 1000)
#   Page 11: 100 companies (running total: 1100)
#   Page 12: 100 companies (running total: 1200)
#   Page 13: 100 companies (running total: 1300)
#   Page 14: 100 companies (running total: 1400)
#   Page 15: 100 companies (running total: 1500)
#   Page 16: 100 companies (running total: 1600)
#   Page 17: 100 companies (running total: 1700)
#   Page 18: 100 companies (running total: 1800)
#   Page 19: 100 companies (running total: 1900)
#   Page 20: 100 companies (running total: 2000)
#   Page 21: 100 companies (running total: 2100)
#   Page 22: 100 companies (running total: 2200)
#   Page 23: 100 companies (running total: 2300)
#   Page 24: 100 companies (running total: 2400)
#   Page 25: 100 companies (running total: 2500)
#   Page 26: 100 companies (running total: 2600)
#   Page 27: 100 companies (running total: 2700)
#   Page 28: 100 companies (running total: 2800)
#   Page 29: 100 companies (running total: 2900)
#   Page 30: 100 companies (running total: 3000)
#   Page 31: 100 companies (running total: 3100)
#   Page 32: 100 companies (running total: 3200)
#   Page 33: 100 companies (running total: 3300)
#   Page 34: 100 companies (running total: 3400)
#   Page 35: 100 companies (running total: 3500)
#   Page 36: 100 companies (running total: 3600)
#   Page 37: 100 companies (running total: 3700)
#   Page 38: 100 companies (running total: 3800)
#   Page 39: 100 companies (running total: 3900)
#   Page 40: 100 companies (running total: 4000)
#   Page 41: 100 companies (running total: 4100)
#   Page 42: 100 companies (running total: 4200)
#   Page 43: 100 companies (running total: 4300)
#   Page 44: 100 companies (running total: 4400)
#   Page 45: 100 companies (running total: 4500)
#   Page 46: 100 companies (running total: 4600)
#   Page 47: 100 companies (running total: 4700)
#   Page 48: 100 companies (running total: 4800)
#   Page 49: 100 companies (running total: 4900)
#   Page 50: 100 companies (running total: 5000)
#   Page 51: 100 companies (running total: 5100)
#   Page 52: 100 companies (running total: 5200)
#   Page 53: 100 companies (running total: 5300)
#   Page 54: 100 companies (running total: 5400)
#   Page 55: 100 companies (running total: 5500)
#   Page 56: 100 companies (running total: 5600)
#   Page 57: 100 companies (running total: 5700)
#   Page 58: 100 companies (running total: 5800)
#   Page 59: 100 companies (running total: 5900)
#   Page 60: 100 companies (running total: 6000)
#   Page 61: 100 companies (running total: 6100)
#   Page 62: 100 companies (running total: 6200)
#   Page 63: 100 companies (running total: 6300)
#   Page 64: 100 companies (running total: 6400)
#   Page 65: 100 companies (running total: 6500)
#   Page 66: 100 companies (running total: 6600)
#   Page 67: 100 companies (running total: 6700)
#   Page 68: 100 companies (running total: 6800)
#   Page 69: 100 companies (running total: 6900)
#   Page 70: 100 companies (running total: 7000)
#   Page 71: 100 companies (running total: 7100)
#   Page 72: 100 companies (running total: 7200)
#   Page 73: 100 companies (running total: 7300)
#   Page 74: 100 companies (running total: 7400)
#   Page 75: 100 companies (running total: 7500)
#   Page 76: 100 companies (running total: 7600)
#   Page 77: 100 companies (running total: 7700)
#   Page 78: 100 companies (running total: 7800)
#   Page 79: 100 companies (running total: 7900)
#   Page 80: 100 companies (running total: 8000)
#   Page 81: 100 companies (running total: 8100)
#   Page 82: 100 companies (running total: 8200)
#   Page 83: 100 companies (running total: 8300)
#   Page 84: 5 companies (running total: 8305)
#   Completed: 8305 total companies
#
# Searching SIC code: 62012
#   Page 1: 100 companies (running total: 8405)
#   Page 2: 100 companies (running total: 8505)
#   Page 3: 100 companies (running total: 8605)
#   Page 4: 100 companies (running total: 8705)
#   Page 5: 100 companies (running total: 8805)
#   Page 6: 100 companies (running total: 8905)
#   Page 7: 100 companies (running total: 9005)
#   Page 8: 100 companies (running total: 9105)
#   Page 9: 100 companies (running total: 9205)
#   Page 10: 100 companies (running total: 9305)
#   Page 11: 100 companies (running total: 9405)
#   Page 12: 100 companies (running total: 9505)
#   Page 13: 100 companies (running total: 9605)
#   Page 14: 100 companies (running total: 9705)
#   Page 15: 100 companies (running total: 9805)
#   Page 16: 100 companies (running total: 9905)
#   Page 17: 100 companies (running total: 10005)
#   Page 18: 100 companies (running total: 10105)
#   Page 19: 100 companies (running total: 10205)
#   Page 20: 100 companies (running total: 10305)
#   Page 21: 100 companies (running total: 10405)
#   Page 22: 100 companies (running total: 10505)
#   Page 23: 100 companies (running total: 10605)
#   Page 24: 100 companies (running total: 10705)
#   Page 25: 100 companies (running total: 10805)
#   Page 26: 100 companies (running total: 10905)
#   Page 27: 100 companies (running total: 11005)
#   Page 28: 100 companies (running total: 11105)
#   Page 29: 100 companies (running total: 11205)
#   Page 30: 100 companies (running total: 11305)
#   Page 31: 100 companies (running total: 11405)
#   Page 32: 100 companies (running total: 11505)
#   Page 33: 100 companies (running total: 11605)
#   Page 34: 100 companies (running total: 11705)
#   Page 35: 100 companies (running total: 11805)
#   Page 36: 100 companies (running total: 11905)
#   Page 37: 100 companies (running total: 12005)
#   Page 38: 100 companies (running total: 12105)
#   Page 39: 100 companies (running total: 12205)
#   Page 40: 100 companies (running total: 12305)
#   Page 41: 100 companies (running total: 12405)
#   Page 42: 100 companies (running total: 12505)
#   Page 43: 100 companies (running total: 12605)
#   Page 44: 100 companies (running total: 12705)
#   Page 45: 100 companies (running total: 12805)
#   Page 46: 100 companies (running total: 12905)
#   Page 47: 100 companies (running total: 13005)
#   Page 48: 100 companies (running total: 13105)
#   Page 49: 100 companies (running total: 13205)
#   Page 50: 100 companies (running total: 13305)
#   Page 51: 100 companies (running total: 13405)
#   Page 52: 100 companies (running total: 13505)
#   Page 53: 100 companies (running total: 13605)
#   Page 54: 100 companies (running total: 13705)
#   Page 55: 100 companies (running total: 13805)
#   Page 56: 100 companies (running total: 13905)
#   Page 57: 100 companies (running total: 14005)
#   Page 58: 100 companies (running total: 14105)
#   Page 59: 100 companies (running total: 14205)
#   Page 60: 100 companies (running total: 14305)
#   Page 61: 100 companies (running total: 14405)
#   Page 62: 100 companies (running total: 14505)
#   Page 63: 100 companies (running total: 14605)
#   Page 64: 100 companies (running total: 14705)
#   Page 65: 100 companies (running total: 14805)
#   Page 66: 100 companies (running total: 14905)
#   Page 67: 100 companies (running total: 15005)
#   Page 68: 100 companies (running total: 15105)
#   Page 69: 100 companies (running total: 15205)
#   Page 70: 100 companies (running total: 15305)
#   Page 71: 100 companies (running total: 15405)
#   Page 72: 100 companies (running total: 15505)
#   Page 73: 100 companies (running total: 15605)
#   Page 74: 100 companies (running total: 15705)
#   Page 75: 100 companies (running total: 15805)
#   Page 76: 100 companies (running total: 15905)
#   Page 77: 100 companies (running total: 16005)
#   Page 78: 100 companies (running total: 16105)
#   Page 79: 100 companies (running total: 16205)
#   Page 80: 100 companies (running total: 16305)
#   Page 81: 100 companies (running total: 16405)
#   Page 82: 100 companies (running total: 16505)
#   Page 83: 100 companies (running total: 16605)
#   Page 84: 100 companies (running total: 16705)
#   Page 85: 100 companies (running total: 16805)
#   Page 86: 100 companies (running total: 16905)
#   Page 87: 100 companies (running total: 17005)
#   Page 88: 100 companies (running total: 17105)
#   Page 89: 100 companies (running total: 17205)
#   Page 90: 100 companies (running total: 17305)
#   Page 91: 100 companies (running total: 17405)
#   Page 92: 100 companies (running total: 17505)
#   Page 93: 100 companies (running total: 17605)
#   Page 94: 100 companies (running total: 17705)
#   Page 95: 100 companies (running total: 17805)
#   Page 96: 100 companies (running total: 17905)
#   Page 97: 100 companies (running total: 18005)
#   Page 98: 100 companies (running total: 18105)
#   Page 99: 100 companies (running total: 18205)
#   Page 100: 100 companies (running total: 18305)
#   Error 500: {"timestamp":"2025-11-19T19:03:45.991+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 62020
#   Page 1: 100 companies (running total: 18405)
#   Page 2: 100 companies (running total: 18505)
#   Page 3: 100 companies (running total: 18605)
#   Page 4: 100 companies (running total: 18705)
#   Page 5: 100 companies (running total: 18805)
#   Page 6: 100 companies (running total: 18905)
#   Page 7: 100 companies (running total: 19005)
#   Page 8: 100 companies (running total: 19105)
#   Page 9: 100 companies (running total: 19205)
#   Page 10: 100 companies (running total: 19305)
#   Page 11: 100 companies (running total: 19405)
#   Page 12: 100 companies (running total: 19505)
#   Page 13: 100 companies (running total: 19605)
#   Page 14: 100 companies (running total: 19705)
#   Page 15: 100 companies (running total: 19805)
#   Page 16: 100 companies (running total: 19905)
#   Page 17: 100 companies (running total: 20005)
#   Page 18: 100 companies (running total: 20105)
#   Page 19: 100 companies (running total: 20205)
#   Page 20: 100 companies (running total: 20305)
#   Page 21: 100 companies (running total: 20405)
#   Page 22: 100 companies (running total: 20505)
#   Page 23: 100 companies (running total: 20605)
#   Page 24: 100 companies (running total: 20705)
#   Page 25: 100 companies (running total: 20805)
#   Page 26: 100 companies (running total: 20905)
#   Page 27: 100 companies (running total: 21005)
#   Page 28: 100 companies (running total: 21105)
#   Page 29: 100 companies (running total: 21205)
#   Page 30: 100 companies (running total: 21305)
#   Page 31: 100 companies (running total: 21405)
#   Page 32: 100 companies (running total: 21505)
#   Page 33: 100 companies (running total: 21605)
#   Page 34: 100 companies (running total: 21705)
#   Page 35: 100 companies (running total: 21805)
#   Page 36: 100 companies (running total: 21905)
#   Page 37: 100 companies (running total: 22005)
#   Page 38: 100 companies (running total: 22105)
#   Page 39: 100 companies (running total: 22205)
#   Page 40: 100 companies (running total: 22305)
#   Page 41: 100 companies (running total: 22405)
#   Page 42: 100 companies (running total: 22505)
#   Page 43: 100 companies (running total: 22605)
#   Page 44: 100 companies (running total: 22705)
#   Page 45: 100 companies (running total: 22805)
#   Page 46: 100 companies (running total: 22905)
#   Page 47: 100 companies (running total: 23005)
#   Page 48: 100 companies (running total: 23105)
#   Page 49: 100 companies (running total: 23205)
#   Page 50: 100 companies (running total: 23305)
#   Page 51: 100 companies (running total: 23405)
#   Page 52: 100 companies (running total: 23505)
#   Page 53: 100 companies (running total: 23605)
#   Page 54: 100 companies (running total: 23705)
#   Page 55: 100 companies (running total: 23805)
#   Page 56: 100 companies (running total: 23905)
#   Page 57: 100 companies (running total: 24005)
#   Page 58: 100 companies (running total: 24105)
#   Page 59: 100 companies (running total: 24205)
#   Page 60: 100 companies (running total: 24305)
#   Page 61: 100 companies (running total: 24405)
#   Page 62: 100 companies (running total: 24505)
#   Page 63: 100 companies (running total: 24605)
#   Page 64: 100 companies (running total: 24705)
#   Page 65: 100 companies (running total: 24805)
#   Page 66: 100 companies (running total: 24905)
#   Page 67: 100 companies (running total: 25005)
#   Page 68: 100 companies (running total: 25105)
#   Page 69: 100 companies (running total: 25205)
#   Page 70: 100 companies (running total: 25305)
#   Page 71: 100 companies (running total: 25405)
#   Page 72: 100 companies (running total: 25505)
#   Page 73: 100 companies (running total: 25605)
#   Page 74: 100 companies (running total: 25705)
#   Page 75: 100 companies (running total: 25805)
#   Page 76: 100 companies (running total: 25905)
#   Page 77: 100 companies (running total: 26005)
#   Page 78: 100 companies (running total: 26105)
#   Page 79: 100 companies (running total: 26205)
#   Page 80: 100 companies (running total: 26305)
#   Page 81: 100 companies (running total: 26405)
#   Page 82: 100 companies (running total: 26505)
#   Page 83: 100 companies (running total: 26605)
#   Page 84: 100 companies (running total: 26705)
#   Page 85: 100 companies (running total: 26805)
#   Page 86: 100 companies (running total: 26905)
#   Page 87: 100 companies (running total: 27005)
#   Page 88: 100 companies (running total: 27105)
#   Page 89: 100 companies (running total: 27205)
#   Page 90: 100 companies (running total: 27305)
#   Page 91: 100 companies (running total: 27405)
#   Page 92: 100 companies (running total: 27505)
#   Page 93: 100 companies (running total: 27605)
#   Page 94: 100 companies (running total: 27705)
#   Page 95: 100 companies (running total: 27805)
#   Page 96: 100 companies (running total: 27905)
#   Page 97: 100 companies (running total: 28005)
#   Page 98: 100 companies (running total: 28105)
#   Page 99: 100 companies (running total: 28205)
#   Page 100: 100 companies (running total: 28305)
#   Error 500: {"timestamp":"2025-11-19T19:04:45.492+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 62090
#   Page 1: 100 companies (running total: 28405)
#   Page 2: 100 companies (running total: 28505)
#   Page 3: 100 companies (running total: 28605)
#   Page 4: 100 companies (running total: 28705)
#   Page 5: 100 companies (running total: 28805)
#   Page 6: 100 companies (running total: 28905)
#   Page 7: 100 companies (running total: 29005)
#   Page 8: 100 companies (running total: 29105)
#   Page 9: 100 companies (running total: 29205)
#   Page 10: 100 companies (running total: 29305)
#   Page 11: 100 companies (running total: 29405)
#   Page 12: 100 companies (running total: 29505)
#   Page 13: 100 companies (running total: 29605)
#   Page 14: 100 companies (running total: 29705)
#   Page 15: 100 companies (running total: 29805)
#   Page 16: 100 companies (running total: 29905)
#   Page 17: 100 companies (running total: 30005)
#   Page 18: 100 companies (running total: 30105)
#   Page 19: 100 companies (running total: 30205)
#   Page 20: 100 companies (running total: 30305)
#   Page 21: 100 companies (running total: 30405)
#   Page 22: 100 companies (running total: 30505)
#   Page 23: 100 companies (running total: 30605)
#   Page 24: 100 companies (running total: 30705)
#   Page 25: 100 companies (running total: 30805)
#   Page 26: 100 companies (running total: 30905)
#   Page 27: 100 companies (running total: 31005)
#   Page 28: 100 companies (running total: 31105)
#   Page 29: 100 companies (running total: 31205)
#   Page 30: 100 companies (running total: 31305)
#   Page 31: 100 companies (running total: 31405)
#   Page 32: 100 companies (running total: 31505)
#   Page 33: 100 companies (running total: 31605)
#   Page 34: 100 companies (running total: 31705)
#   Page 35: 100 companies (running total: 31805)
#   Page 36: 100 companies (running total: 31905)
#   Page 37: 100 companies (running total: 32005)
#   Page 38: 100 companies (running total: 32105)
#   Page 39: 100 companies (running total: 32205)
#   Page 40: 100 companies (running total: 32305)
#   Page 41: 100 companies (running total: 32405)
#   Page 42: 100 companies (running total: 32505)
#   Page 43: 100 companies (running total: 32605)
#   Page 44: 100 companies (running total: 32705)
#   Page 45: 100 companies (running total: 32805)
#   Page 46: 100 companies (running total: 32905)
#   Page 47: 100 companies (running total: 33005)
#   Page 48: 100 companies (running total: 33105)
#   Page 49: 100 companies (running total: 33205)
#   Page 50: 100 companies (running total: 33305)
#   Page 51: 100 companies (running total: 33405)
#   Page 52: 100 companies (running total: 33505)
#   Page 53: 100 companies (running total: 33605)
#   Page 54: 100 companies (running total: 33705)
#   Page 55: 100 companies (running total: 33805)
#   Page 56: 100 companies (running total: 33905)
#   Page 57: 100 companies (running total: 34005)
#   Page 58: 100 companies (running total: 34105)
#   Page 59: 100 companies (running total: 34205)
#   Page 60: 100 companies (running total: 34305)
#   Page 61: 100 companies (running total: 34405)
#   Page 62: 100 companies (running total: 34505)
#   Page 63: 100 companies (running total: 34605)
#   Page 64: 100 companies (running total: 34705)
#   Page 65: 100 companies (running total: 34805)
#   Page 66: 100 companies (running total: 34905)
#   Page 67: 100 companies (running total: 35005)
#   Page 68: 100 companies (running total: 35105)
#   Page 69: 100 companies (running total: 35205)
#   Page 70: 100 companies (running total: 35305)
#   Page 71: 100 companies (running total: 35405)
#   Page 72: 100 companies (running total: 35505)
#   Page 73: 100 companies (running total: 35605)
#   Page 74: 100 companies (running total: 35705)
#   Page 75: 100 companies (running total: 35805)
#   Page 76: 100 companies (running total: 35905)
#   Page 77: 100 companies (running total: 36005)
#   Page 78: 100 companies (running total: 36105)
#   Page 79: 100 companies (running total: 36205)
#   Page 80: 100 companies (running total: 36305)
#   Page 81: 100 companies (running total: 36405)
#   Page 82: 100 companies (running total: 36505)
#   Page 83: 100 companies (running total: 36605)
#   Page 84: 100 companies (running total: 36705)
#   Page 85: 100 companies (running total: 36805)
#   Page 86: 100 companies (running total: 36905)
#   Page 87: 100 companies (running total: 37005)
#   Page 88: 100 companies (running total: 37105)
#   Page 89: 100 companies (running total: 37205)
#   Page 90: 100 companies (running total: 37305)
#   Page 91: 100 companies (running total: 37405)
#   Page 92: 100 companies (running total: 37505)
#   Page 93: 100 companies (running total: 37605)
#   Page 94: 100 companies (running total: 37705)
#   Page 95: 100 companies (running total: 37805)
#   Page 96: 100 companies (running total: 37905)
#   Page 97: 100 companies (running total: 38005)
#   Page 98: 100 companies (running total: 38105)
#   Page 99: 100 companies (running total: 38205)
#   Page 100: 100 companies (running total: 38305)
#   Error 500: {"timestamp":"2025-11-19T19:05:45.827+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 63110
#   Page 1: 100 companies (running total: 38405)
#   Page 2: 100 companies (running total: 38505)
#   Page 3: 100 companies (running total: 38605)
#   Page 4: 100 companies (running total: 38705)
#   Page 5: 100 companies (running total: 38805)
#   Page 6: 100 companies (running total: 38905)
#   Page 7: 100 companies (running total: 39005)
#   Page 8: 100 companies (running total: 39105)
#   Page 9: 100 companies (running total: 39205)
#   Page 10: 100 companies (running total: 39305)
#   Page 11: 100 companies (running total: 39405)
#   Page 12: 100 companies (running total: 39505)
#   Page 13: 100 companies (running total: 39605)
#   Page 14: 100 companies (running total: 39705)
#   Page 15: 100 companies (running total: 39805)
#   Page 16: 100 companies (running total: 39905)
#   Page 17: 100 companies (running total: 40005)
#   Page 18: 100 companies (running total: 40105)
#   Page 19: 100 companies (running total: 40205)
#   Page 20: 100 companies (running total: 40305)
#   Page 21: 100 companies (running total: 40405)
#   Page 22: 100 companies (running total: 40505)
#   Page 23: 100 companies (running total: 40605)
#   Page 24: 100 companies (running total: 40705)
#   Page 25: 100 companies (running total: 40805)
#   Page 26: 100 companies (running total: 40905)
#   Page 27: 100 companies (running total: 41005)
#   Page 28: 100 companies (running total: 41105)
#   Page 29: 100 companies (running total: 41205)
#   Page 30: 100 companies (running total: 41305)
#   Page 31: 100 companies (running total: 41405)
#   Page 32: 100 companies (running total: 41505)
#   Page 33: 100 companies (running total: 41605)
#   Page 34: 100 companies (running total: 41705)
#   Page 35: 100 companies (running total: 41805)
#   Page 36: 100 companies (running total: 41905)
#   Page 37: 100 companies (running total: 42005)
#   Page 38: 100 companies (running total: 42105)
#   Page 39: 100 companies (running total: 42205)
#   Page 40: 100 companies (running total: 42305)
#   Page 41: 100 companies (running total: 42405)
#   Page 42: 100 companies (running total: 42505)
#   Page 43: 100 companies (running total: 42605)
#   Page 44: 100 companies (running total: 42705)
#   Page 45: 100 companies (running total: 42805)
#   Page 46: 100 companies (running total: 42905)
#   Page 47: 100 companies (running total: 43005)
#   Page 48: 100 companies (running total: 43105)
#   Page 49: 100 companies (running total: 43205)
#   Page 50: 100 companies (running total: 43305)
#   Page 51: 100 companies (running total: 43405)
#   Page 52: 100 companies (running total: 43505)
#   Page 53: 100 companies (running total: 43605)
#   Page 54: 100 companies (running total: 43705)
#   Page 55: 100 companies (running total: 43805)
#   Page 56: 100 companies (running total: 43905)
#   Page 57: 100 companies (running total: 44005)
#   Page 58: 100 companies (running total: 44105)
#   Page 59: 100 companies (running total: 44205)
#   Page 60: 100 companies (running total: 44305)
#   Page 61: 100 companies (running total: 44405)
#   Page 62: 100 companies (running total: 44505)
#   Page 63: 100 companies (running total: 44605)
#   Page 64: 100 companies (running total: 44705)
#   Page 65: 100 companies (running total: 44805)
#   Page 66: 100 companies (running total: 44905)
#   Page 67: 100 companies (running total: 45005)
#   Page 68: 100 companies (running total: 45105)
#   Page 69: 100 companies (running total: 45205)
#   Page 70: 100 companies (running total: 45305)
#   Page 71: 100 companies (running total: 45405)
#   Page 72: 100 companies (running total: 45505)
#   Page 73: 100 companies (running total: 45605)
#   Page 74: 100 companies (running total: 45705)
#   Page 75: 100 companies (running total: 45805)
#   Page 76: 100 companies (running total: 45905)
#   Page 77: 100 companies (running total: 46005)
#   Page 78: 100 companies (running total: 46105)
#   Page 79: 100 companies (running total: 46205)
#   Page 80: 100 companies (running total: 46305)
#   Page 81: 100 companies (running total: 46405)
#   Page 82: 100 companies (running total: 46505)
#   Page 83: 100 companies (running total: 46605)
#   Page 84: 100 companies (running total: 46705)
#   Page 85: 100 companies (running total: 46805)
#   Page 86: 100 companies (running total: 46905)
#   Page 87: 100 companies (running total: 47005)
#   Page 88: 100 companies (running total: 47105)
#   Page 89: 100 companies (running total: 47205)
#   Page 90: 100 companies (running total: 47305)
#   Page 91: 100 companies (running total: 47405)
#   Page 92: 100 companies (running total: 47505)
#   Page 93: 100 companies (running total: 47605)
#   Page 94: 100 companies (running total: 47705)
#   Page 95: 100 companies (running total: 47805)
#   Page 96: 100 companies (running total: 47905)
#   Page 97: 100 companies (running total: 48005)
#   Page 98: 100 companies (running total: 48105)
#   Page 99: 100 companies (running total: 48205)
#   Page 100: 100 companies (running total: 48305)
#   Error 500: {"timestamp":"2025-11-19T19:06:45.787+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 63120
#   Page 1: 100 companies (running total: 48405)
#   Page 2: 100 companies (running total: 48505)
#   Page 3: 100 companies (running total: 48605)
#   Page 4: 100 companies (running total: 48705)
#   Page 5: 100 companies (running total: 48805)
#   Page 6: 100 companies (running total: 48905)
#   Page 7: 100 companies (running total: 49005)
#   Page 8: 100 companies (running total: 49105)
#   Page 9: 100 companies (running total: 49205)
#   Page 10: 100 companies (running total: 49305)
#   Page 11: 100 companies (running total: 49405)
#   Page 12: 100 companies (running total: 49505)
#   Page 13: 100 companies (running total: 49605)
#   Page 14: 100 companies (running total: 49705)
#   Page 15: 100 companies (running total: 49805)
#   Page 16: 100 companies (running total: 49905)
#   Page 17: 100 companies (running total: 50005)
#   Page 18: 100 companies (running total: 50105)
#   Page 19: 100 companies (running total: 50205)
#   Page 20: 100 companies (running total: 50305)
#   Page 21: 100 companies (running total: 50405)
#   Page 22: 100 companies (running total: 50505)
#   Page 23: 100 companies (running total: 50605)
#   Page 24: 100 companies (running total: 50705)
#   Page 25: 100 companies (running total: 50805)
#   Page 26: 100 companies (running total: 50905)
#   Page 27: 100 companies (running total: 51005)
#   Page 28: 100 companies (running total: 51105)
#   Page 29: 100 companies (running total: 51205)
#   Page 30: 100 companies (running total: 51305)
#   Page 31: 100 companies (running total: 51405)
#   Page 32: 100 companies (running total: 51505)
#   Page 33: 100 companies (running total: 51605)
#   Page 34: 100 companies (running total: 51705)
#   Page 35: 100 companies (running total: 51805)
#   Page 36: 100 companies (running total: 51905)
#   Page 37: 100 companies (running total: 52005)
#   Page 38: 100 companies (running total: 52105)
#   Page 39: 100 companies (running total: 52205)
#   Page 40: 100 companies (running total: 52305)
#   Page 41: 100 companies (running total: 52405)
#   Page 42: 100 companies (running total: 52505)
#   Page 43: 100 companies (running total: 52605)
#   Page 44: 100 companies (running total: 52705)
#   Page 45: 100 companies (running total: 52805)
#   Page 46: 100 companies (running total: 52905)
#   Page 47: 100 companies (running total: 53005)
#   Page 48: 100 companies (running total: 53105)
#   Page 49: 100 companies (running total: 53205)
#   Page 50: 100 companies (running total: 53305)
#   Page 51: 100 companies (running total: 53405)
#   Page 52: 100 companies (running total: 53505)
#   Page 53: 100 companies (running total: 53605)
#   Page 54: 100 companies (running total: 53705)
#   Page 55: 100 companies (running total: 53805)
#   Page 56: 100 companies (running total: 53905)
#   Page 57: 100 companies (running total: 54005)
#   Page 58: 100 companies (running total: 54105)
#   Page 59: 100 companies (running total: 54205)
#   Page 60: 100 companies (running total: 54305)
#   Page 61: 100 companies (running total: 54405)
#   Page 62: 100 companies (running total: 54505)
#   Page 63: 100 companies (running total: 54605)
#   Page 64: 100 companies (running total: 54705)
#   Page 65: 100 companies (running total: 54805)
#   Page 66: 100 companies (running total: 54905)
#   Page 67: 100 companies (running total: 55005)
#   Page 68: 100 companies (running total: 55105)
#   Page 69: 100 companies (running total: 55205)
#   Page 70: 100 companies (running total: 55305)
#   Page 71: 100 companies (running total: 55405)
#   Page 72: 100 companies (running total: 55505)
#   Page 73: 100 companies (running total: 55605)
#   Page 74: 100 companies (running total: 55705)
#   Page 75: 100 companies (running total: 55805)
#   Page 76: 100 companies (running total: 55905)
#   Page 77: 100 companies (running total: 56005)
#   Page 78: 100 companies (running total: 56105)
#   Page 79: 100 companies (running total: 56205)
#   Page 80: 100 companies (running total: 56305)
#   Page 81: 100 companies (running total: 56405)
#   Page 82: 100 companies (running total: 56505)
#   Page 83: 100 companies (running total: 56605)
#   Page 84: 100 companies (running total: 56705)
#   Page 85: 100 companies (running total: 56805)
#   Page 86: 100 companies (running total: 56905)
#   Page 87: 100 companies (running total: 57005)
#   Page 88: 100 companies (running total: 57105)
#   Page 89: 100 companies (running total: 57205)
#   Page 90: 100 companies (running total: 57305)
#   Page 91: 100 companies (running total: 57405)
#   Page 92: 100 companies (running total: 57505)
#   Page 93: 100 companies (running total: 57605)
#   Page 94: 100 companies (running total: 57705)
#   Page 95: 100 companies (running total: 57805)
#   Page 96: 100 companies (running total: 57905)
#   Page 97: 100 companies (running total: 58005)
#   Page 98: 100 companies (running total: 58105)
#   Page 99: 100 companies (running total: 58205)
#   Page 100: 100 companies (running total: 58305)
#   Error 500: {"timestamp":"2025-11-19T19:07:45.273+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 63990
#   Page 1: 100 companies (running total: 58405)
#   Page 2: 100 companies (running total: 58505)
#   Page 3: 100 companies (running total: 58605)
#   Page 4: 100 companies (running total: 58705)
#   Page 5: 100 companies (running total: 58805)
#   Page 6: 100 companies (running total: 58905)
#   Page 7: 100 companies (running total: 59005)
#   Page 8: 100 companies (running total: 59105)
#   Page 9: 100 companies (running total: 59205)
#   Page 10: 100 companies (running total: 59305)
#   Page 11: 100 companies (running total: 59405)
#   Page 12: 100 companies (running total: 59505)
#   Page 13: 100 companies (running total: 59605)
#   Page 14: 100 companies (running total: 59705)
#   Page 15: 100 companies (running total: 59805)
#   Page 16: 100 companies (running total: 59905)
#   Page 17: 100 companies (running total: 60005)
#   Page 18: 100 companies (running total: 60105)
#   Page 19: 100 companies (running total: 60205)
#   Page 20: 100 companies (running total: 60305)
#   Page 21: 100 companies (running total: 60405)
#   Page 22: 100 companies (running total: 60505)
#   Page 23: 100 companies (running total: 60605)
#   Page 24: 100 companies (running total: 60705)
#   Page 25: 100 companies (running total: 60805)
#   Page 26: 100 companies (running total: 60905)
#   Page 27: 100 companies (running total: 61005)
#   Page 28: 100 companies (running total: 61105)
#   Page 29: 100 companies (running total: 61205)
#   Page 30: 100 companies (running total: 61305)
#   Page 31: 100 companies (running total: 61405)
#   Page 32: 100 companies (running total: 61505)
#   Page 33: 100 companies (running total: 61605)
#   Page 34: 100 companies (running total: 61705)
#   Page 35: 100 companies (running total: 61805)
#   Page 36: 100 companies (running total: 61905)
#   Page 37: 100 companies (running total: 62005)
#   Page 38: 100 companies (running total: 62105)
#   Page 39: 100 companies (running total: 62205)
#   Page 40: 100 companies (running total: 62305)
#   Page 41: 100 companies (running total: 62405)
#   Page 42: 100 companies (running total: 62505)
#   Page 43: 100 companies (running total: 62605)
#   Page 44: 100 companies (running total: 62705)
#   Page 45: 100 companies (running total: 62805)
#   Page 46: 100 companies (running total: 62905)
#   Page 47: 100 companies (running total: 63005)
#   Page 48: 100 companies (running total: 63105)
#   Page 49: 100 companies (running total: 63205)
#   Page 50: 100 companies (running total: 63305)
#   Page 51: 100 companies (running total: 63405)
#   Page 52: 100 companies (running total: 63505)
#   Page 53: 100 companies (running total: 63605)
#   Page 54: 100 companies (running total: 63705)
#   Page 55: 100 companies (running total: 63805)
#   Page 56: 100 companies (running total: 63905)
#   Page 57: 100 companies (running total: 64005)
#   Page 58: 100 companies (running total: 64105)
#   Page 59: 100 companies (running total: 64205)
#   Page 60: 100 companies (running total: 64305)
#   Page 61: 100 companies (running total: 64405)
#   Page 62: 100 companies (running total: 64505)
#   Page 63: 100 companies (running total: 64605)
#   Page 64: 100 companies (running total: 64705)
#   Page 65: 100 companies (running total: 64805)
#   Page 66: 100 companies (running total: 64905)
#   Page 67: 100 companies (running total: 65005)
#   Page 68: 100 companies (running total: 65105)
#   Page 69: 100 companies (running total: 65205)
#   Page 70: 100 companies (running total: 65305)
#   Page 71: 100 companies (running total: 65405)
#   Page 72: 100 companies (running total: 65505)
#   Page 73: 100 companies (running total: 65605)
#   Page 74: 100 companies (running total: 65705)
#   Page 75: 100 companies (running total: 65805)
#   Page 76: 100 companies (running total: 65905)
#   Page 77: 100 companies (running total: 66005)
#   Page 78: 100 companies (running total: 66105)
#   Page 79: 100 companies (running total: 66205)
#   Page 80: 100 companies (running total: 66305)
#   Page 81: 100 companies (running total: 66405)
#   Page 82: 100 companies (running total: 66505)
#   Page 83: 100 companies (running total: 66605)
#   Page 84: 100 companies (running total: 66705)
#   Page 85: 100 companies (running total: 66805)
#   Page 86: 100 companies (running total: 66905)
#   Page 87: 100 companies (running total: 67005)
#   Page 88: 100 companies (running total: 67105)
#   Page 89: 100 companies (running total: 67205)
#   Page 90: 100 companies (running total: 67305)
#   Page 91: 100 companies (running total: 67405)
#   Page 92: 100 companies (running total: 67505)
#   Page 93: 100 companies (running total: 67605)
#   Page 94: 100 companies (running total: 67705)
#   Page 95: 100 companies (running total: 67805)
#   Page 96: 100 companies (running total: 67905)
#   Page 97: 100 companies (running total: 68005)
#   Page 98: 100 companies (running total: 68105)
#   Page 99: 100 companies (running total: 68205)
#   Page 100: 100 companies (running total: 68305)
#   Error 500: {"timestamp":"2025-11-19T19:08:44.697+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 58210
#   Page 1: 100 companies (running total: 68405)
#   Page 2: 100 companies (running total: 68505)
#   Page 3: 100 companies (running total: 68605)
#   Page 4: 100 companies (running total: 68705)
#   Page 5: 100 companies (running total: 68805)
#   Page 6: 100 companies (running total: 68905)
#   Page 7: 100 companies (running total: 69005)
#   Page 8: 100 companies (running total: 69105)
#   Page 9: 100 companies (running total: 69205)
#   Page 10: 100 companies (running total: 69305)
#   Page 11: 100 companies (running total: 69405)
#   Page 12: 100 companies (running total: 69505)
#   Page 13: 100 companies (running total: 69605)
#   Page 14: 100 companies (running total: 69705)
#   Page 15: 100 companies (running total: 69805)
#   Page 16: 100 companies (running total: 69905)
#   Page 17: 100 companies (running total: 70005)
#   Page 18: 100 companies (running total: 70105)
#   Page 19: 100 companies (running total: 70205)
#   Page 20: 100 companies (running total: 70305)
#   Page 21: 100 companies (running total: 70405)
#   Page 22: 100 companies (running total: 70505)
#   Page 23: 100 companies (running total: 70605)
#   Page 24: 100 companies (running total: 70705)
#   Page 25: 100 companies (running total: 70805)
#   Page 26: 100 companies (running total: 70905)
#   Page 27: 100 companies (running total: 71005)
#   Page 28: 100 companies (running total: 71105)
#   Page 29: 100 companies (running total: 71205)
#   Page 30: 100 companies (running total: 71305)
#   Page 31: 100 companies (running total: 71405)
#   Page 32: 100 companies (running total: 71505)
#   Page 33: 100 companies (running total: 71605)
#   Page 34: 100 companies (running total: 71705)
#   Page 35: 100 companies (running total: 71805)
#   Page 36: 100 companies (running total: 71905)
#   Page 37: 100 companies (running total: 72005)
#   Page 38: 100 companies (running total: 72105)
#   Page 39: 100 companies (running total: 72205)
#   Page 40: 100 companies (running total: 72305)
#   Page 41: 100 companies (running total: 72405)
#   Page 42: 100 companies (running total: 72505)
#   Page 43: 100 companies (running total: 72605)
#   Page 44: 100 companies (running total: 72705)
#   Page 45: 100 companies (running total: 72805)
#   Page 46: 100 companies (running total: 72905)
#   Page 47: 100 companies (running total: 73005)
#   Page 48: 89 companies (running total: 73094)
#   Completed: 73094 total companies
#
# Searching SIC code: 58290
#   Page 1: 100 companies (running total: 73194)
#   Page 2: 100 companies (running total: 73294)
#   Page 3: 100 companies (running total: 73394)
#   Page 4: 100 companies (running total: 73494)
#   Page 5: 100 companies (running total: 73594)
#   Page 6: 100 companies (running total: 73694)
#   Page 7: 100 companies (running total: 73794)
#   Page 8: 100 companies (running total: 73894)
#   Page 9: 100 companies (running total: 73994)
#   Page 10: 100 companies (running total: 74094)
#   Page 11: 100 companies (running total: 74194)
#   Page 12: 100 companies (running total: 74294)
#   Page 13: 100 companies (running total: 74394)
#   Page 14: 100 companies (running total: 74494)
#   Page 15: 100 companies (running total: 74594)
#   Page 16: 100 companies (running total: 74694)
#   Page 17: 100 companies (running total: 74794)
#   Page 18: 100 companies (running total: 74894)
#   Page 19: 100 companies (running total: 74994)
#   Page 20: 100 companies (running total: 75094)
#   Page 21: 100 companies (running total: 75194)
#   Page 22: 100 companies (running total: 75294)
#   Page 23: 100 companies (running total: 75394)
#   Page 24: 100 companies (running total: 75494)
#   Page 25: 100 companies (running total: 75594)
#   Page 26: 100 companies (running total: 75694)
#   Page 27: 100 companies (running total: 75794)
#   Page 28: 100 companies (running total: 75894)
#   Page 29: 100 companies (running total: 75994)
#   Page 30: 100 companies (running total: 76094)
#   Page 31: 100 companies (running total: 76194)
#   Page 32: 100 companies (running total: 76294)
#   Page 33: 100 companies (running total: 76394)
#   Page 34: 100 companies (running total: 76494)
#   Page 35: 100 companies (running total: 76594)
#   Page 36: 100 companies (running total: 76694)
#   Page 37: 100 companies (running total: 76794)
#   Page 38: 100 companies (running total: 76894)
#   Page 39: 100 companies (running total: 76994)
#   Page 40: 100 companies (running total: 77094)
#   Page 41: 100 companies (running total: 77194)
#   Page 42: 100 companies (running total: 77294)
#   Page 43: 100 companies (running total: 77394)
#   Page 44: 100 companies (running total: 77494)
#   Page 45: 100 companies (running total: 77594)
#   Page 46: 100 companies (running total: 77694)
#   Page 47: 100 companies (running total: 77794)
#   Page 48: 100 companies (running total: 77894)
#   Page 49: 100 companies (running total: 77994)
#   Page 50: 100 companies (running total: 78094)
#   Page 51: 100 companies (running total: 78194)
#   Page 52: 100 companies (running total: 78294)
#   Page 53: 100 companies (running total: 78394)
#   Page 54: 100 companies (running total: 78494)
#   Page 55: 100 companies (running total: 78594)
#   Page 56: 100 companies (running total: 78694)
#   Page 57: 100 companies (running total: 78794)
#   Page 58: 100 companies (running total: 78894)
#   Page 59: 100 companies (running total: 78994)
#   Page 60: 100 companies (running total: 79094)
#   Page 61: 100 companies (running total: 79194)
#   Page 62: 100 companies (running total: 79294)
#   Page 63: 100 companies (running total: 79394)
#   Page 64: 100 companies (running total: 79494)
#   Page 65: 100 companies (running total: 79594)
#   Page 66: 100 companies (running total: 79694)
#   Page 67: 100 companies (running total: 79794)
#   Page 68: 100 companies (running total: 79894)
#   Page 69: 100 companies (running total: 79994)
#   Page 70: 100 companies (running total: 80094)
#   Page 71: 100 companies (running total: 80194)
#   Page 72: 100 companies (running total: 80294)
#   Page 73: 100 companies (running total: 80394)
#   Page 74: 100 companies (running total: 80494)
#   Page 75: 100 companies (running total: 80594)
#   Page 76: 100 companies (running total: 80694)
#   Page 77: 100 companies (running total: 80794)
#   Page 78: 100 companies (running total: 80894)
#   Page 79: 100 companies (running total: 80994)
#   Page 80: 100 companies (running total: 81094)
#   Page 81: 100 companies (running total: 81194)
#   Page 82: 100 companies (running total: 81294)
#   Page 83: 100 companies (running total: 81394)
#   Page 84: 100 companies (running total: 81494)
#   Page 85: 100 companies (running total: 81594)
#   Page 86: 100 companies (running total: 81694)
#   Page 87: 100 companies (running total: 81794)
#   Page 88: 100 companies (running total: 81894)
#   Page 89: 100 companies (running total: 81994)
#   Page 90: 100 companies (running total: 82094)
#   Page 91: 100 companies (running total: 82194)
#   Page 92: 100 companies (running total: 82294)
#   Page 93: 100 companies (running total: 82394)
#   Page 94: 100 companies (running total: 82494)
#   Page 95: 100 companies (running total: 82594)
#   Page 96: 100 companies (running total: 82694)
#   Page 97: 100 companies (running total: 82794)
#   Page 98: 100 companies (running total: 82894)
#   Page 99: 100 companies (running total: 82994)
#   Page 100: 100 companies (running total: 83094)
#   Error 500: {"timestamp":"2025-11-19T19:10:13.008+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 26200
#   Page 1: 100 companies (running total: 83194)
#   Page 2: 100 companies (running total: 83294)
#   Page 3: 100 companies (running total: 83394)
#   Page 4: 100 companies (running total: 83494)
#   Page 5: 100 companies (running total: 83594)
#   Page 6: 100 companies (running total: 83694)
#   Page 7: 100 companies (running total: 83794)
#   Page 8: 100 companies (running total: 83894)
#   Page 9: 5 companies (running total: 83899)
#   Completed: 83899 total companies
#
# Searching SIC code: 95110
#   Page 1: 100 companies (running total: 83999)
#   Page 2: 100 companies (running total: 84099)
#   Page 3: 100 companies (running total: 84199)
#   Page 4: 100 companies (running total: 84299)
#   Page 5: 100 companies (running total: 84399)
#   Page 6: 100 companies (running total: 84499)
#   Page 7: 100 companies (running total: 84599)
#   Page 8: 100 companies (running total: 84699)
#   Page 9: 100 companies (running total: 84799)
#   Page 10: 100 companies (running total: 84899)
#   Page 11: 100 companies (running total: 84999)
#   Page 12: 100 companies (running total: 85099)
#   Page 13: 100 companies (running total: 85199)
#   Page 14: 100 companies (running total: 85299)
#   Page 15: 100 companies (running total: 85399)
#   Page 16: 100 companies (running total: 85499)
#   Page 17: 100 companies (running total: 85599)
#   Page 18: 100 companies (running total: 85699)
#   Page 19: 100 companies (running total: 85799)
#   Page 20: 100 companies (running total: 85899)
#   Page 21: 100 companies (running total: 85999)
#   Page 22: 100 companies (running total: 86099)
#   Page 23: 100 companies (running total: 86199)
#   Page 24: 100 companies (running total: 86299)
#   Page 25: 100 companies (running total: 86399)
#   Page 26: 100 companies (running total: 86499)
#   Page 27: 100 companies (running total: 86599)
#   Page 28: 100 companies (running total: 86699)
#   Page 29: 100 companies (running total: 86799)
#   Page 30: 100 companies (running total: 86899)
#   Page 31: 100 companies (running total: 86999)
#   Page 32: 100 companies (running total: 87099)
#   Page 33: 100 companies (running total: 87199)
#   Page 34: 100 companies (running total: 87299)
#   Page 35: 100 companies (running total: 87399)
#   Page 36: 100 companies (running total: 87499)
#   Page 37: 100 companies (running total: 87599)
#   Page 38: 14 companies (running total: 87613)
#   Completed: 87613 total companies
#
# Searching SIC code: 64190
#   Error 404:
#
# Searching SIC code: 64999
#   Page 1: 100 companies (running total: 87713)
#   Page 2: 100 companies (running total: 87813)
#   Page 3: 100 companies (running total: 87913)
#   Page 4: 100 companies (running total: 88013)
#   Page 5: 100 companies (running total: 88113)
#   Page 6: 100 companies (running total: 88213)
#   Page 7: 100 companies (running total: 88313)
#   Page 8: 100 companies (running total: 88413)
#   Page 9: 100 companies (running total: 88513)
#   Page 10: 100 companies (running total: 88613)
#   Page 11: 100 companies (running total: 88713)
#   Page 12: 100 companies (running total: 88813)
#   Page 13: 100 companies (running total: 88913)
#   Page 14: 100 companies (running total: 89013)
#   Page 15: 100 companies (running total: 89113)
#   Page 16: 100 companies (running total: 89213)
#   Page 17: 100 companies (running total: 89313)
#   Page 18: 100 companies (running total: 89413)
#   Page 19: 100 companies (running total: 89513)
#   Page 20: 100 companies (running total: 89613)
#   Page 21: 100 companies (running total: 89713)
#   Page 22: 100 companies (running total: 89813)
#   Page 23: 100 companies (running total: 89913)
#   Page 24: 100 companies (running total: 90013)
#   Page 25: 100 companies (running total: 90113)
#   Page 26: 100 companies (running total: 90213)
#   Page 27: 100 companies (running total: 90313)
#   Page 28: 100 companies (running total: 90413)
#   Page 29: 100 companies (running total: 90513)
#   Page 30: 100 companies (running total: 90613)
#   Page 31: 100 companies (running total: 90713)
#   Page 32: 100 companies (running total: 90813)
#   Page 33: 100 companies (running total: 90913)
#   Page 34: 100 companies (running total: 91013)
#   Page 35: 100 companies (running total: 91113)
#   Page 36: 100 companies (running total: 91213)
#   Page 37: 100 companies (running total: 91313)
#   Page 38: 100 companies (running total: 91413)
#   Page 39: 100 companies (running total: 91513)
#   Page 40: 100 companies (running total: 91613)
#   Page 41: 100 companies (running total: 91713)
#   Page 42: 100 companies (running total: 91813)
#   Page 43: 100 companies (running total: 91913)
#   Page 44: 100 companies (running total: 92013)
#   Page 45: 100 companies (running total: 92113)
#   Page 46: 100 companies (running total: 92213)
#   Page 47: 100 companies (running total: 92313)
#   Page 48: 100 companies (running total: 92413)
#   Page 49: 100 companies (running total: 92513)
#   Page 50: 100 companies (running total: 92613)
#   Page 51: 100 companies (running total: 92713)
#   Page 52: 100 companies (running total: 92813)
#   Page 53: 100 companies (running total: 92913)
#   Page 54: 100 companies (running total: 93013)
#   Page 55: 100 companies (running total: 93113)
#   Page 56: 100 companies (running total: 93213)
#   Page 57: 100 companies (running total: 93313)
#   Page 58: 100 companies (running total: 93413)
#   Page 59: 100 companies (running total: 93513)
#   Page 60: 100 companies (running total: 93613)
#   Page 61: 100 companies (running total: 93713)
#   Page 62: 100 companies (running total: 93813)
#   Page 63: 100 companies (running total: 93913)
#   Page 64: 100 companies (running total: 94013)
#   Page 65: 100 companies (running total: 94113)
#   Page 66: 100 companies (running total: 94213)
#   Page 67: 100 companies (running total: 94313)
#   Page 68: 100 companies (running total: 94413)
#   Page 69: 100 companies (running total: 94513)
#   Page 70: 100 companies (running total: 94613)
#   Page 71: 100 companies (running total: 94713)
#   Page 72: 100 companies (running total: 94813)
#   Page 73: 100 companies (running total: 94913)
#   Page 74: 100 companies (running total: 95013)
#   Page 75: 100 companies (running total: 95113)
#   Page 76: 100 companies (running total: 95213)
#   Page 77: 100 companies (running total: 95313)
#   Page 78: 100 companies (running total: 95413)
#   Page 79: 100 companies (running total: 95513)
#   Page 80: 100 companies (running total: 95613)
#   Page 81: 100 companies (running total: 95713)
#   Page 82: 100 companies (running total: 95813)
#   Page 83: 100 companies (running total: 95913)
#   Page 84: 100 companies (running total: 96013)
#   Page 85: 100 companies (running total: 96113)
#   Page 86: 100 companies (running total: 96213)
#   Page 87: 100 companies (running total: 96313)
#   Page 88: 100 companies (running total: 96413)
#   Page 89: 100 companies (running total: 96513)
#   Page 90: 100 companies (running total: 96613)
#   Page 91: 100 companies (running total: 96713)
#   Page 92: 100 companies (running total: 96813)
#   Page 93: 100 companies (running total: 96913)
#   Page 94: 100 companies (running total: 97013)
#   Page 95: 100 companies (running total: 97113)
#   Page 96: 100 companies (running total: 97213)
# ...
#   Page 91: 100 companies (running total: 124377)
#   Page 92: 100 companies (running total: 124477)
#   Page 93: 100 companies (running total: 124577)
#   Page 94: 100 companies (running total: 124677)
#   Page 95: 100 companies (running total: 124777)
#   Page 96: 100 companies (running total: 124877)
#   Page 97: 100 companies (running total: 124977)
#   Page 98: 100 companies (running total: 125077)
#   Page 99: 100 companies (running total: 125177)
#   Page 100: 100 companies (running total: 125277)
#   Error 500: {"timestamp":"2025-11-19T19:14:27.235+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 73120
#   Page 1: 100 companies (running total: 125377)
#   Page 2: 100 companies (running total: 125477)
#   Page 3: 100 companies (running total: 125577)
#   Page 4: 100 companies (running total: 125677)
#   Page 5: 100 companies (running total: 125777)
#   Page 6: 100 companies (running total: 125877)
#   Page 7: 100 companies (running total: 125977)
#   Page 8: 100 companies (running total: 126077)
#   Page 9: 100 companies (running total: 126177)
#   Page 10: 100 companies (running total: 126277)
#   Page 11: 100 companies (running total: 126377)
#   Page 12: 100 companies (running total: 126477)
#   Page 13: 100 companies (running total: 126577)
#   Page 14: 100 companies (running total: 126677)
#   Page 15: 100 companies (running total: 126777)
#   Page 16: 100 companies (running total: 126877)
#   Page 17: 100 companies (running total: 126977)
#   Page 18: 100 companies (running total: 127077)
#   Page 19: 100 companies (running total: 127177)
#   Page 20: 100 companies (running total: 127277)
#   Page 21: 100 companies (running total: 127377)
#   Page 22: 100 companies (running total: 127477)
#   Page 23: 100 companies (running total: 127577)
#   Page 24: 100 companies (running total: 127677)
#   Page 25: 100 companies (running total: 127777)
#   Page 26: 100 companies (running total: 127877)
#   Page 27: 100 companies (running total: 127977)
#   Page 28: 100 companies (running total: 128077)
#   Page 29: 100 companies (running total: 128177)
#   Page 30: 100 companies (running total: 128277)
#   Page 31: 100 companies (running total: 128377)
#   Page 32: 100 companies (running total: 128477)
#   Page 33: 100 companies (running total: 128577)
#   Page 34: 100 companies (running total: 128677)
#   Page 35: 100 companies (running total: 128777)
#   Page 36: 100 companies (running total: 128877)
#   Page 37: 100 companies (running total: 128977)
#   Page 38: 100 companies (running total: 129077)
#   Page 39: 100 companies (running total: 129177)
#   Page 40: 100 companies (running total: 129277)
#   Page 41: 100 companies (running total: 129377)
#   Page 42: 100 companies (running total: 129477)
#   Page 43: 100 companies (running total: 129577)
#   Page 44: 100 companies (running total: 129677)
#   Page 45: 100 companies (running total: 129777)
#   Page 46: 100 companies (running total: 129877)
#   Page 47: 100 companies (running total: 129977)
#   Page 48: 100 companies (running total: 130077)
#   Page 49: 100 companies (running total: 130177)
#   Page 50: 100 companies (running total: 130277)
#   Page 51: 100 companies (running total: 130377)
#   Page 52: 100 companies (running total: 130477)
#   Page 53: 100 companies (running total: 130577)
#   Page 54: 100 companies (running total: 130677)
#   Page 55: 100 companies (running total: 130777)
#   Page 56: 100 companies (running total: 130877)
#   Page 57: 100 companies (running total: 130977)
#   Page 58: 100 companies (running total: 131077)
#   Page 59: 100 companies (running total: 131177)
#   Page 60: 100 companies (running total: 131277)
#   Page 61: 100 companies (running total: 131377)
#   Page 62: 100 companies (running total: 131477)
#   Page 63: 100 companies (running total: 131577)
#   Page 64: 100 companies (running total: 131677)
#   Page 65: 100 companies (running total: 131777)
#   Page 66: 100 companies (running total: 131877)
#   Page 67: 100 companies (running total: 131977)
#   Page 68: 100 companies (running total: 132077)
#   Page 69: 100 companies (running total: 132177)
#   Page 70: 100 companies (running total: 132277)
#   Page 71: 100 companies (running total: 132377)
#   Page 72: 100 companies (running total: 132477)
#   Page 73: 100 companies (running total: 132577)
#   Page 74: 100 companies (running total: 132677)
#   Page 75: 100 companies (running total: 132777)
#   Page 76: 100 companies (running total: 132877)
#   Page 77: 100 companies (running total: 132977)
#   Page 78: 100 companies (running total: 133077)
#   Page 79: 100 companies (running total: 133177)
#   Page 80: 100 companies (running total: 133277)
#   Page 81: 100 companies (running total: 133377)
#   Page 82: 100 companies (running total: 133477)
#   Page 83: 100 companies (running total: 133577)
#   Page 84: 100 companies (running total: 133677)
#   Page 85: 100 companies (running total: 133777)
#   Page 86: 100 companies (running total: 133877)
#   Page 87: 100 companies (running total: 133977)
#   Page 88: 100 companies (running total: 134077)
#   Page 89: 100 companies (running total: 134177)
#   Page 90: 100 companies (running total: 134277)
#   Page 91: 100 companies (running total: 134377)
#   Page 92: 100 companies (running total: 134477)
#   Page 93: 100 companies (running total: 134577)
#   Page 94: 100 companies (running total: 134677)
#   Page 95: 100 companies (running total: 134777)
#   Page 96: 100 companies (running total: 134877)
#   Page 97: 100 companies (running total: 134977)
#   Page 98: 100 companies (running total: 135077)
#   Page 99: 100 companies (running total: 135177)
#   Page 100: 100 companies (running total: 135277)
#   Error 500: {"timestamp":"2025-11-19T19:15:26.728+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 82990
#   Page 1: 100 companies (running total: 135377)
#   Page 2: 100 companies (running total: 135477)
#   Page 3: 100 companies (running total: 135577)
#   Page 4: 100 companies (running total: 135677)
#   Page 5: 100 companies (running total: 135777)
#   Page 6: 100 companies (running total: 135877)
#   Page 7: 100 companies (running total: 135977)
#   Page 8: 100 companies (running total: 136077)
#   Page 9: 100 companies (running total: 136177)
#   Page 10: 100 companies (running total: 136277)
#   Page 11: 100 companies (running total: 136377)
#   Page 12: 100 companies (running total: 136477)
#   Page 13: 100 companies (running total: 136577)
#   Page 14: 100 companies (running total: 136677)
#   Page 15: 100 companies (running total: 136777)
#   Page 16: 100 companies (running total: 136877)
#   Page 17: 100 companies (running total: 136977)
#   Page 18: 100 companies (running total: 137077)
#   Page 19: 100 companies (running total: 137177)
#   Page 20: 100 companies (running total: 137277)
#   Page 21: 100 companies (running total: 137377)
#   Page 22: 100 companies (running total: 137477)
#   Page 23: 100 companies (running total: 137577)
#   Page 24: 100 companies (running total: 137677)
#   Page 25: 100 companies (running total: 137777)
#   Page 26: 100 companies (running total: 137877)
#   Page 27: 100 companies (running total: 137977)
#   Page 28: 100 companies (running total: 138077)
#   Page 29: 100 companies (running total: 138177)
#   Page 30: 100 companies (running total: 138277)
#   Page 31: 100 companies (running total: 138377)
#   Page 32: 100 companies (running total: 138477)
#   Page 33: 100 companies (running total: 138577)
#   Page 34: 100 companies (running total: 138677)
#   Page 35: 100 companies (running total: 138777)
#   Page 36: 100 companies (running total: 138877)
#   Page 37: 100 companies (running total: 138977)
#   Page 38: 100 companies (running total: 139077)
#   Page 39: 100 companies (running total: 139177)
#   Page 40: 100 companies (running total: 139277)
#   Page 41: 100 companies (running total: 139377)
#   Page 42: 100 companies (running total: 139477)
#   Page 43: 100 companies (running total: 139577)
#   Page 44: 100 companies (running total: 139677)
#   Page 45: 100 companies (running total: 139777)
#   Page 46: 100 companies (running total: 139877)
#   Page 47: 100 companies (running total: 139977)
#   Page 48: 100 companies (running total: 140077)
#   Page 49: 100 companies (running total: 140177)
#   Page 50: 100 companies (running total: 140277)
#   Page 51: 100 companies (running total: 140377)
#   Page 52: 100 companies (running total: 140477)
#   Page 53: 100 companies (running total: 140577)
#   Page 54: 100 companies (running total: 140677)
#   Page 55: 100 companies (running total: 140777)
#   Page 56: 100 companies (running total: 140877)
#   Page 57: 100 companies (running total: 140977)
#   Page 58: 100 companies (running total: 141077)
#   Page 59: 100 companies (running total: 141177)
#   Page 60: 100 companies (running total: 141277)
#   Page 61: 100 companies (running total: 141377)
#   Page 62: 100 companies (running total: 141477)
#   Page 63: 100 companies (running total: 141577)
#   Page 64: 100 companies (running total: 141677)
#   Page 65: 100 companies (running total: 141777)
#   Page 66: 100 companies (running total: 141877)
#   Page 67: 100 companies (running total: 141977)
#   Page 68: 100 companies (running total: 142077)
#   Page 69: 100 companies (running total: 142177)
#   Page 70: 100 companies (running total: 142277)
#   Page 71: 100 companies (running total: 142377)
#   Page 72: 100 companies (running total: 142477)
#   Page 73: 100 companies (running total: 142577)
#   Page 74: 100 companies (running total: 142677)
#   Page 75: 100 companies (running total: 142777)
#   Page 76: 100 companies (running total: 142877)
#   Page 77: 100 companies (running total: 142977)
#   Page 78: 100 companies (running total: 143077)
#   Page 79: 100 companies (running total: 143177)
#   Page 80: 100 companies (running total: 143277)
#   Page 81: 100 companies (running total: 143377)
#   Page 82: 100 companies (running total: 143477)
#   Page 83: 100 companies (running total: 143577)
#   Page 84: 100 companies (running total: 143677)
#   Page 85: 100 companies (running total: 143777)
#   Page 86: 100 companies (running total: 143877)
#   Page 87: 100 companies (running total: 143977)
#   Page 88: 100 companies (running total: 144077)
#   Page 89: 100 companies (running total: 144177)
#   Page 90: 100 companies (running total: 144277)
#   Page 91: 100 companies (running total: 144377)
#   Page 92: 100 companies (running total: 144477)
#   Page 93: 100 companies (running total: 144577)
#   Page 94: 100 companies (running total: 144677)
#   Page 95: 100 companies (running total: 144777)
#   Page 96: 100 companies (running total: 144877)
#   Page 97: 100 companies (running total: 144977)
#   Page 98: 100 companies (running total: 145077)
#   Page 99: 100 companies (running total: 145177)
#   Page 100: 100 companies (running total: 145277)
#   Error 500: {"timestamp":"2025-11-19T19:16:26.849+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# Searching SIC code: 47910
#   Page 1: 100 companies (running total: 145377)
#   Page 2: 100 companies (running total: 145477)
#   Page 3: 100 companies (running total: 145577)
#   Page 4: 100 companies (running total: 145677)
#   Page 5: 100 companies (running total: 145777)
#   Page 6: 100 companies (running total: 145877)
#   Page 7: 100 companies (running total: 145977)
#   Page 8: 100 companies (running total: 146077)
#   Page 9: 100 companies (running total: 146177)
#   Page 10: 100 companies (running total: 146277)
#   Page 11: 100 companies (running total: 146377)
#   Page 12: 100 companies (running total: 146477)
#   Page 13: 100 companies (running total: 146577)
#   Page 14: 100 companies (running total: 146677)
#   Page 15: 100 companies (running total: 146777)
#   Page 16: 100 companies (running total: 146877)
#   Page 17: 100 companies (running total: 146977)
#   Page 18: 100 companies (running total: 147077)
#   Page 19: 100 companies (running total: 147177)
#   Page 20: 100 companies (running total: 147277)
#   Page 21: 100 companies (running total: 147377)
#   Page 22: 100 companies (running total: 147477)
#   Page 23: 100 companies (running total: 147577)
#   Page 24: 100 companies (running total: 147677)
#   Page 25: 100 companies (running total: 147777)
#   Page 26: 100 companies (running total: 147877)
#   Page 27: 100 companies (running total: 147977)
#   Page 28: 100 companies (running total: 148077)
#   Page 29: 100 companies (running total: 148177)
#   Page 30: 100 companies (running total: 148277)
#   Page 31: 100 companies (running total: 148377)
#   Page 32: 100 companies (running total: 148477)
#   Page 33: 100 companies (running total: 148577)
#   Page 34: 100 companies (running total: 148677)
#   Page 35: 100 companies (running total: 148777)
#   Page 36: 100 companies (running total: 148877)
#   Page 37: 100 companies (running total: 148977)
#   Page 38: 100 companies (running total: 149077)
#   Page 39: 100 companies (running total: 149177)
#   Page 40: 100 companies (running total: 149277)
#   Page 41: 100 companies (running total: 149377)
#   Page 42: 100 companies (running total: 149477)
#   Page 43: 100 companies (running total: 149577)
#   Page 44: 100 companies (running total: 149677)
#   Page 45: 100 companies (running total: 149777)
#   Page 46: 100 companies (running total: 149877)
#   Page 47: 100 companies (running total: 149977)
#   Page 48: 100 companies (running total: 150077)
#   Page 49: 100 companies (running total: 150177)
#   Page 50: 100 companies (running total: 150277)
#   Page 51: 100 companies (running total: 150377)
#   Page 52: 100 companies (running total: 150477)
#   Page 53: 100 companies (running total: 150577)
#   Page 54: 100 companies (running total: 150677)
#   Page 55: 100 companies (running total: 150777)
#   Page 56: 100 companies (running total: 150877)
#   Page 57: 100 companies (running total: 150977)
#   Page 58: 100 companies (running total: 151077)
#   Page 59: 100 companies (running total: 151177)
#   Page 60: 100 companies (running total: 151277)
#   Page 61: 100 companies (running total: 151377)
#   Page 62: 100 companies (running total: 151477)
#   Page 63: 100 companies (running total: 151577)
#   Page 64: 100 companies (running total: 151677)
#   Page 65: 100 companies (running total: 151777)
#   Page 66: 100 companies (running total: 151877)
#   Page 67: 100 companies (running total: 151977)
#   Page 68: 100 companies (running total: 152077)
#   Page 69: 100 companies (running total: 152177)
#   Page 70: 100 companies (running total: 152277)
#   Page 71: 100 companies (running total: 152377)
#   Page 72: 100 companies (running total: 152477)
#   Page 73: 100 companies (running total: 152577)
#   Page 74: 100 companies (running total: 152677)
#   Page 75: 100 companies (running total: 152777)
#   Page 76: 100 companies (running total: 152877)
#   Page 77: 100 companies (running total: 152977)
#   Page 78: 100 companies (running total: 153077)
#   Page 79: 100 companies (running total: 153177)
#   Page 80: 100 companies (running total: 153277)
#   Page 81: 100 companies (running total: 153377)
#   Page 82: 100 companies (running total: 153477)
#   Page 83: 100 companies (running total: 153577)
#   Page 84: 100 companies (running total: 153677)
#   Page 85: 100 companies (running total: 153777)
#   Page 86: 100 companies (running total: 153877)
#   Page 87: 100 companies (running total: 153977)
#   Page 88: 100 companies (running total: 154077)
#   Page 89: 100 companies (running total: 154177)
#   Page 90: 100 companies (running total: 154277)
#   Page 91: 100 companies (running total: 154377)
#   Page 92: 100 companies (running total: 154477)
#   Page 93: 100 companies (running total: 154577)
#   Page 94: 100 companies (running total: 154677)
#   Page 95: 100 companies (running total: 154777)
#   Page 96: 100 companies (running total: 154877)
#   Page 97: 100 companies (running total: 154977)
#   Page 98: 100 companies (running total: 155077)
#   Page 99: 100 companies (running total: 155177)
#   Page 100: 100 companies (running total: 155277)
#   Error 500: {"timestamp":"2025-11-19T19:17:26.811+00:00","status":500,"error":"Internal Server Error","path":"/a
#
# ✓ Search complete!
#   Total requests made: 1572
#   Total unique companies: 155277
#
# ============================================================
# DATA COLLECTION COMPLETE
# ============================================================
# Total companies collected: 155,277

# %% [markdown]
# We define our data extraction function that pulls the key fields we need from each company record: identification (number, name), status, incorporation date, location, and SIC codes. We also timestamp when we retrieved the data.

# %%
def extract_company_details(company_item):
    """
    Extract relevant fields from Companies House search results.
    We clean and structure the data for our database.
    """
    return {
        'company_number': company_item.get('company_number'),
        'company_name': company_item.get('company_name'),
        'company_status': company_item.get('company_status'),
        'date_of_creation': company_item.get('date_of_creation'),
        'company_type': company_item.get('company_type'),
        'address': company_item.get('address', {}).get('postal_code', ''),
        'sic_codes': ', '.join(company_item.get('sic_codes', [])),
        'retrieved_at': datetime.now().isoformat()
    }

# %% [markdown]
# - We convert our raw API results into a clean pandas DataFrame with 155,277 companies.
#
# - We examine the data structure, check for active vs dissolved companies, and see the distribution across our target years (2022-2025).
#
# - This gives us a sense of data quality before we save it to our database.

# %%
# Convert to structured DataFrame
print("Converting to DataFrame...")
companies_df = pd.DataFrame([extract_company_details(c) for c in all_uk_tech_companies])

print(f"DataFrame created: {len(companies_df):,} rows × {len(companies_df.columns)} columns")
print(f"\nDataFrame info:")
print(companies_df.info())
print(f"\nFirst few records:")
print(companies_df.head())
print(f"\nCompany status distribution:")
print(companies_df['company_status'].value_counts())
print(f"\nIncorporation year distribution:")
companies_df['incorporation_year'] = pd.to_datetime(companies_df['date_of_creation']).dt.year
print(companies_df['incorporation_year'].value_counts().sort_index())
# Out:
# Converting to DataFrame...
# DataFrame created: 155,277 rows × 8 columns
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155277 entries, 0 to 155276
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   company_number    155277 non-null  object
#  1   company_name      155277 non-null  object
#  2   company_status    155277 non-null  object
#  3   date_of_creation  155277 non-null  object
#  4   company_type      155277 non-null  object
#  5   address           155277 non-null  object
#  6   sic_codes         155277 non-null  object
#  7   retrieved_at      155277 non-null  object
# dtypes: object(8)
# memory usage: 9.5+ MB
# None
#
# First few records:
#   company_number           company_name company_status date_of_creation  \
# 0       14451923   UNREAL SOLUTIONS LTD         active       2022-10-31
# 1       15719845     HORA STARS LIMITED         active       2024-05-14
# 2       14299198           MONICONS LTD         active       2022-08-16
# 3       13983357  ANGDIM TECHNOLOGY LTD         active       2022-03-17
# 4       14440295         FITSESSION LTD         active       2022-10-25
#
#   company_type address                   sic_codes                retrieved_at
# 0          ltd                 62011, 62012, 62020  2025-11-20T00:49:59.930838
# 1          ltd                               62011  2025-11-20T00:49:59.930838
# 2          ltd          62011, 62012, 62020, 78300  2025-11-20T00:49:59.930838
# 3          ltd                 62011, 62012, 71122  2025-11-20T00:49:59.930838
# 4          ltd          58290, 62011, 62012, 62020  2025-11-20T00:49:59.930838
#
# Company status distribution:
# company_status
# active              95031
# dissolved           60151
# liquidation            86
# administration          6
# converted-closed        3
# Name: count, dtype: int64
#
# Incorporation year distribution:
# incorporation_year
# 2022    50107
# 2023    45493
# 2024    36515
# 2025    23162
# Name: count, dtype: int64
